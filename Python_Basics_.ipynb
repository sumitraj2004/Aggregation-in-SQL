# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitraj2004/Aggregation-in-SQL/blob/main/Python_Basics_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python Basics

# %% [markdown]
# Question 1: What is Python and why is it widely used in Data Analytics? Mention any three reasons.
# Answer:
#
# Python is a high-level, easy-to-learn programming language widely used in Data Analytics for data processing, visualization, and machine learning.
#
# Reasons:
#
# Python has simple and readable syntax.
# It provides powerful libraries like Pandas, NumPy, and Matplotlib.
# It can efficiently handle large datasets and automate data analysis tasks.
# Question 2: Explain the difference between List and Tuple in Python.
# Answer:
# List	Tuple
# Mutable (can be modified)	Immutable (cannot be modified)
# Uses square brackets []	Uses parentheses ()
# Slower than tuple	Faster than list
# Example: [1,2,3]	Example: (1,2,3)
#
# Question 3: What is a function in Python? Why are functions useful?
#
# Answer:
#
# A function is a reusable block of code that performs a specific task. Functions reduce code repetition, improve readability, and make programs easier to maintain and debug.
#
# Question 4: Write a Python program to take a user's name as input and print a greeting message.
#
# Answer:
#
# name = input("Enter your name: ")
# print("Hello,", name + "! Welcome to Python.")
# Question 5: Write a Python program to check whether a number is even or odd using conditional statements.
# Answer:
# num = int(input("Enter a number: "))
#
# if num % 2 == 0:
#     print("Even Number")
# else:
#     print("Odd Number")
#
# Question 6: Write a program to print numbers from 1 to 10 using a loop.
#
# Answer:
#
# for i in range(1, 11):
#     print(i)
#
# Question 7: Create a list of five numbers and print the maximum number from the list.
#
# Answer:
#
# numbers = [12, 45, 8, 90, 25]
#
# print("Maximum Number:", max(numbers))
#
# Question 8: Write a Python program to remove duplicate values from a list using a set.
#
# Answer:
#
# numbers = [2, 3, 4, 2, 5, 2]
#
# unique_numbers = list(set(numbers))
#
# print(unique_numbers)
#
# Question 9: Write a function that returns the square of a number.
#
# Answer:
# \
# def square(num):
#     return num ** 2
#
# print(square(5))
#
# Question 10: Write a Python program to count how many times a number appears in a list.
#
# Example List: [2, 3, 4, 2, 5, 2]
#
# Answer:
#
# numbers = [2, 3, 4, 2, 5, 2]
#
# num = int(input("Enter number to count: "))
#
# count = numbers.count(num)
#
# print("Occurrences:", count)
