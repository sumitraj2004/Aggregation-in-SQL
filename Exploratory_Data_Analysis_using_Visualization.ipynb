# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitraj2004/Aggregation-in-SQL/blob/main/Exploratory_Data_Analysis_using_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exploratory Data Analysis using Visualization

# %% [markdown]
# Q1. Create a countplot to show the number of passengers by gender.
#
# Answer:
#
# Result:
# Male passengers = 577
# Female passengers = 314
# Interpretation:
#
# The countplot shows that the Titanic dataset contains more male passengers than female passengers. There were 577 male passengers and 314 female passengers.
#
# Q2. Create a bar chart to show the number of passengers in each passenger class using different colors.
#
# Answer:
#
# Result:
# First Class = 216 passengers
# Second Class = 184 passengers
# Third Class = 491 passengers
# Interpretation:
#
# The bar chart shows that Third Class had the highest number of passengers with 491 passengers. First Class had 216 passengers, while Second Class had the lowest number with 184 passengers.
#
# Q3. Create a histogram to show the distribution of passenger age.
#
# Answer:
#
# Interpretation:
#
# The histogram shows the distribution of passenger ages. The average age of the passengers with available age information is approximately 29.7 years. The youngest passenger was approximately 0.42 years old, while the oldest passenger was 80 years old.
#
# Most passengers were young and middle-aged adults, while comparatively fewer passengers were elderly.
#
# Q4. Create a boxplot to detect outliers in the fare column.
#
# Answer:
#
# Result:
# Median Fare = 14.45
# Maximum Fare = 512.33
# Interpretation:
#
# The boxplot shows that the Fare column contains several high-value outliers. Most passengers paid relatively low fares, while a small number of passengers paid extremely high fares.
#
# These high fare values may represent passengers travelling in higher passenger classes or purchasing expensive tickets.
#
# Q5. Create a scatterplot to:
# a. Show the relationship between age and fare.
#
# Answer:
#
# Interpretation:
#
# The scatterplot shows the relationship between passenger age and fare. The correlation between Age and Fare is approximately 0.096, which indicates a very weak positive relationship.
#
# This means that passenger age did not have a strong relationship with the fare paid.
#
# b. Analyze the relationship between family size (SibSp + Parch) and fare.
#
# Answer:
#
# Interpretation:
#
# Family Size is calculated by adding the number of siblings/spouses (SibSp) and parents/children (Parch).
#
# The correlation between Family Size and Fare is approximately 0.217, indicating a weak positive relationship.
#
# This means that passengers travelling with larger family groups generally tended to have somewhat higher fares, but the relationship was not very strong.
#
# Q6. Create a countplot to show survival count by gender.
#
# Answer:
#
# Result:
# Gender	Did Not Survive	Survived
# Female	81	233
# Male	468	109
# Interpretation:
#
# The countplot clearly shows a major difference in survival between males and females.
#
# Out of the female passengers, 233 survived and 81 did not survive. Among male passengers, only 109 survived, while 468 did not survive.
#
# Therefore, female passengers had a significantly higher survival rate than male passengers.
#
# Q7. Create a bar chart to show survival by passenger class.
#
# Answer:
#
# Result:
# Passenger Class	Did Not Survive	Survived
# First Class	80	136
# Second Class	97	87
# Third Class	372	119
# Interpretation:
#
# The bar chart shows that passenger class had a strong relationship with survival.
#
# First Class had the highest survival rate, with 136 out of 216 passengers surviving, which is approximately 63.0%.
#
# Second Class had a survival rate of approximately 47.3%.
#
# Third Class had the lowest survival rate, with 119 out of 491 passengers surviving, which is approximately 24.2%.
#
# Therefore, passengers travelling in higher classes generally had better chances of survival.
#
# Q8. Create a heatmap to show correlation between numerical variables.
#
# Answer:
#
# Interpretation:
#
# The correlation heatmap shows the relationships between different numerical variables.
#
# There is a negative relationship between Pclass and Survived, meaning passengers in lower-numbered classes, especially First Class, generally had better survival chances.
#
# Fare has a positive relationship with survival, indicating that passengers who paid higher fares generally had better survival chances.
#
# Age has only a weak relationship with survival. Family Size also has a relatively weak relationship with the other variables.
#
# Q9. Identify which passenger class paid the highest fare on average.
#
# Answer:
#
# Result:
# First Class = 84.15
# Second Class = 20.66
# Third Class = 13.68
#
# Therefore, First Class passengers paid the highest average fare.
#
# Interpretation:
#
# First Class passengers paid considerably higher fares than Second Class and Third Class passengers. The average fare for First Class was approximately 84.15, while Third Class had an average fare of approximately 13.68.
#
# This indicates that passenger class was strongly associated with ticket fare.
#
# Q10. Write at least 5 insights from the dataset based on your visualizations.
#
# Answer:
#
# The Titanic dataset contains 577 male passengers and 314 female passengers, showing that male passengers were more numerous than female passengers.
# Third Class had the highest number of passengers, with 491 passengers, while Second Class had the lowest number with 184 passengers.
# Female passengers had a much higher survival rate than male passengers. Approximately 74.2% of female passengers survived compared with approximately 18.9% of male passengers.
# First Class passengers had the highest survival rate, approximately 63.0%, while Third Class passengers had the lowest survival rate, approximately 24.2%.
# First Class passengers paid the highest average fare, approximately 84.15, compared with 20.66 for Second Class and 13.68 for Third Class.
# The relationship between Age and Fare was very weak, with a correlation of approximately 0.096.
# The relationship between Family Size and Fare was weakly positive, with a correlation of approximately 0.217.
# The Fare column contains several high-value outliers, with the maximum fare being approximately 512.33.
# The visualizations indicate that gender and passenger class were important factors associated with survival.
# Overall, the Titanic data shows that female passengers and passengers travelling in higher classes generally had better chances of survival, while male and Third Class passengers had considerably lower survival rates.
