# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitraj2004/Aggregation-in-SQL/blob/main/Power_BI_Visuals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Power BI Visuals

# %% [markdown]
# Question 1: Create a Card Visual to show Total Sales.
#
# - Answer:
#
# - **Visual:** Card
# - **Field:** Sales (Sum)
#
# **Total Sales = 12,642,501.91**
#
# ---
#
# Question 2: Create a Donut Chart showing Total Sales by Ship Mode and which ship mode generates the highest sales?
#
# - Answer:
#
# - **Visual:** Donut Chart
# - **Legend:** Ship Mode
# - **Values:** Sum of Sales
#
# **Highest Sales:** **Standard Class**
#
# ---
#
# Question 3: Create a Line Chart showing the Sales Trend over time (by Month and Year). Is there any noticeable seasonal pattern in sales?
#
# - Answer:
#
# - **Visual:** Line Chart
# - **X-Axis:** Order Date (Month-Year)
# - **Y-Axis:** Sum of Sales
#
# **Observation:** Sales generally increase toward the end of each year, with the highest sales occurring in **November 2014**.
#
# ---
#
# Question 4: Create a Bar Chart to compare Sales by Category.
#
# - Answer:
#
# - **Visual:** Clustered Bar Chart
# - **Axis:** Category
# - **Values:** Sum of Sales
#
# **Sales by Category:**
# - Technology – Highest
# - Furniture – Second
# - Office Supplies – Third
#
# ---
#
# Question 5: Create a Matrix Visual to display Sales by Month and Category and identify the month with the highest sales.
#
# - Answer:
#
# - **Visual:** Matrix
# - **Rows:** Month
# - **Columns:** Category
# - **Values:** Sum of Sales
#
# **Month with Highest Sales:** **November 2014**
#
# ---
#
# Question 6: Create a Decomposition Tree for Sales Breakdown.
#
# - Answer:
#
# - **Analyze:** Sales
# - **Explain By:** Category → Sub-Category → Region → Market
#
# This visual helps identify the factors contributing to total sales.
#
# ---
#
# Question 7: Create a Scatter Chart to compare Discount vs. Profit by Sub-Category. Are there any outliers where high discounts resulted in negative profit?
#
# - Answer:
#
# - **Visual:** Scatter Chart
# - **X-Axis:** Discount
# - **Y-Axis:** Profit
# - **Details:** Sub-Category
#
# **Observation:** Yes. Several products with **high discounts** resulted in **negative profit**, indicating clear outliers.
#
# ---
#
# Question 8: Use a Funnel Chart to show the number of orders by Customer Segment.
#
# - Answer:
#
# - **Visual:** Funnel Chart
# - **Category:** Segment
# - **Values:** Count of Order ID
#
# **Order Count by Segment:**
# - Consumer – Highest
# - Corporate – Second
# - Home Office – Lowest
#
# ---
#
# Question 9: Use a Waterfall Chart to analyze how Profit changes by Category within the countries.
#
# - Answer:
#
# - **Visual:** Waterfall Chart
# - **Category:** Country
# - **Breakdown:** Category
# - **Y-Axis:** Sum of Profit
#
# **Observation:** The Waterfall Chart shows how each category contributes to profit across different countries.
#
# ---
#
# Question 10: Create a Dual-Axis Line Chart to show Total Sales and Profit Over Time (by Month).
#
# - Answer:
#
# - **Visual:** Line and Clustered Column Chart
# - **Shared Axis:** Order Date (Month)
# - **Column Values:** Sum of Sales
# - **Line Values:** Sum of Profit
#
# **Observation:** Sales and profit generally follow a similar trend, with peak performance observed toward the end of the year.
