# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitraj2004/Aggregation-in-SQL/blob/main/Data_Cleaning_%26_Essential_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Cleaning & Essential Function

# %% [markdown]
# 1: What is data cleaning, and why is it important in data analysis?
#    - Data cleaning is the process of removing errors, duplicates, missing values, and incorrect data to improve data quality.
#
#      Importance:
#
#      Improves accuracy.
#      Ensures reliable analysis.
#      Helps in better decision-making.
#
#      Consequences of unclean data:
#
#      Wrong analysis.
#      Incorrect decisions.
#      Inaccurate reports.
#
#      Steps in data cleaning:
#
#      Remove duplicates.
#      Handle missing values.
#      Correct errors.
#      Standardize data.
#      Validate data.

# %% [markdown]
# 2.Sort the dataset by Department (A–Z) and Salary (Largest to Smallest).
#   - Sorted Data
#      Employee	Department	Salary
#      Pranav	HR	5000
#      Sonu	IT	4000
#      Rahul	IT	2500
#
#      Steps:
#
#      Select the table.
#      Go to Data → Sort.
#      Sort by Department (A–Z).
#      Add Level → Salary (Largest to Smallest).
#      Click OK.

# %% [markdown]
# 3.Explain the use of text functions such as TRIM, LEFT, RIGHT, MID, and CONCAT in data cleaning.
#   -  TRIM: Removes extra spaces.
#      LEFT: Extracts characters from the left.
#      RIGHT: Extracts characters from the right.
#      MID: Extracts characters from the middle.
#      CONCAT: Combines text strings.

# %% [markdown]
# 4.What is the role of date functions like TODAY in managing datasets?
#   -The TODAY() function returns the current date automatically. It is used to  calculate age, due dates, attendance, and date-based reports.
#
#    Formula: =TODAY

# %% [markdown]
# 5.Data Validation (Quantity 1–10)
#   -  Steps:
#
#      Select the Quantity column.
#      Go to Data → Data Validation.
#      Allow: Whole Number.
#      Between: 1 and 10.
#
#      Input Message:
#
#      Title: Quantity
#      Message: Please enter a whole number between 1 and 10.
#
#      Error Alert:
#
#      Title: Invalid Input
#      Message: Invalid input! The quantity must be a whole number between 1 and 10.

# %% [markdown]
# 6.Understand and apply fundamental text functions like LEFT, RIGHT, MID, and   LEN.
#
#  Extract the first 5 characters from the string "ExcelTipsAreGreat" using the LEFT function.
#
#  Extract the last 4 characters from "DataAnalysis.xlsx" using the RIGHT function.
#
#  Extract the substring "Tips" from "ExcelTipsAreGreat" using the MID function.
#
#  Count the total number of characters in the string "Hello World!" using the LEN function.
#
#  Create a formula to extract the middle 6 characters from "12345-67890-ABCDE
#  - a) =LEFT("ExcelTipsAreGreat",5) → Excel
#
#    b) =RIGHT("DataAnalysis.xlsx",4) → xlsx
#
#    c) =MID("ExcelTipsAreGreat",6,4) → Tips
#
#    d) =LEN("Hello World!") → 12
#
#    e) =MID("12345-67890-ABCDE",7,6) → 67890-

# %% [markdown]
# 7.Understand how to combine text using CONCAT, TEXTJOIN, and the & operator.
#
#  Use CONCAT to combine "Hello" and "World" with a space in between.
#
#  Combine "Apple", "Banana", and "Cherry" into a single string separated by commas using TEXTJOIN.
#
#  Use the & operator to create the string "2025: Excel Functions" by combining "2025", ": ", and "Excel
#  Functions".
#
#  Create a comma-separated list from the range A1:A5 using TEXTJOIN
#
#  Combine first names in column A with last names in column B to create full names in column C.
#  - a) =CONCAT("Hello"," ","World")
#    Output: Hello World
#
#    b) =TEXTJOIN(", ",TRUE,"Apple","Banana","Cherry")
#    Output: Apple, Banana, Cherry
#
#    c) ="2025"&": "&"Excel Functions"
#    Output: 2025: Excel Functions
#
#    d) =TEXTJOIN(", ",TRUE,A1:A5)
#    Output: Combines values from A1:A5 separated by commas.
#
#    e) =A2&" "&B2 (or =CONCAT(A2," ",B2))
#    Output: Combines first name and last name into a full name.

# %% [markdown]
# 8.Understanding TODAY() and NOW()
#
#  a. What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use
#  each function.
#
#  b. If cell A1 contains the date 2025-06-10, write a formula using TODAY() to determine how many days are
#
#  left until that date
#
#  c. Write an Excel formula using NOW() to display the current date and time in the format MM/DD/YYYY
#
#  HH:MM AM/PM. ́
#
#  d. If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain
#
#  e. You want to store a static date (today’s date) in a cell without it changing every day. What keyboard
#
#  shortcut should you use?
#  - a) Difference:
#
#    TODAY() returns the current date only.
#    NOW() returns the current date and time.
#
#    b) If A1 contains 2025-06-10:
#    Formula: =A1-TODAY()
#
#    c) Formula: =NOW()
#    Format the cell as MM/DD/YYYY HH:MM AM/PM.
#
#    d) When the worksheet is reopened the next day, =TODAY() automatically updates to the new current date.
#
#    e) To enter a static (fixed) date, use the shortcut: Ctrl + ;
