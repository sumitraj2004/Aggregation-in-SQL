# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitraj2004/Aggregation-in-SQL/blob/main/Publishing_and_Sharing_In_Tableau.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Publishing and Sharing In Tableau

# %% [markdown]
# Tableau Assignment
#
# Question 1: What is the key difference between publishing a dashboard on Tableau Public versus Tableau Server/Cloud in terms of accessibility and data security?
#
# - Answer:
#
# - **Tableau Public:** Dashboards are publicly accessible and data is not secure.
# - **Tableau Server/Cloud:** Dashboards are accessible only to authorized users with secure access and permissions.
#
# ---
#
# Question 2: When publishing a Tableau dashboard, what happens to a live connection compared to an extract? How does this affect data refresh and performance?
#
# - Answer:
#
# - **Live Connection:** Connects directly to the data source and always shows the latest data but may be slower.
# - **Extract:** Stores a snapshot of the data, provides faster performance, and requires scheduled refreshes.
#
# ---
#
# Question 3: In Tableau Server or Cloud (conceptually), which feature allows administrators to control which users can view, interact with, or edit a published dashboard?
#
# - Answer:
#
# **Permissions and User Roles** allow administrators to control who can view, interact with, or edit published dashboards.
#
# ---
#
# Question 4: If you want users to view a dashboard but not download the underlying data, which permission setting would you adjust in Tableau Server?
#
# - Answer:
#
# Disable the **Download Full Data** (or **Download Data**) permission while allowing **View** permission.
#
# ---
#
# Question 5: Name two methods by which a Tableau dashboard can be embedded into a web page or website.
#
# - Answer:
#
# 1. Using the **Embed Code (iframe)**.
# 2. Using the **Tableau JavaScript Embedding API**.
#
# ---
#
# Question 6: List two best practices you should follow when preparing a dashboard for public sharing to ensure data security and privacy.
#
# - Answer:
#
# 1. Remove or mask confidential and personal information.
# 2. Publish only cleaned and non-sensitive data.
#
# ---
#
# Question 7: After publishing a dashboard, users report a "Data not found" error. What is the most common cause related to data source settings?
#
# - Answer:
#
# The most common cause is an incorrect or unavailable data source connection, such as a broken file path, invalid database connection, or missing permissions.
#
# ---
#
# Question 8: When embedding a Tableau dashboard into a secure internal portal, what two additional security measures should be implemented to ensure only authorized users can access the embedded content?
#
# - Answer:
#
# 1. Enable **User Authentication (SSO or Login)**.
# 2. Implement **Role-Based Permissions (User Access Control)**.
